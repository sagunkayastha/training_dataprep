# %%
import glob
import os
import shutil
import pandas as pd
import matplotlib.pyplot as plt

# %%
# for folder in os.listdir("F:\Forecasting_PS\Training_prep\daily_data_0"):
#     try:
#         shutil.rmtree(os.path.join("F:\Forecasting_PS\Training_prep\daily_data_0", folder, 'site_data'))
#     except:
#         pass

# %%
all_files = glob.glob('F:\Forecasting_PS\Training_prep\daily_data_0\ACE\site_data\*.csv')

# %%
for file in all_files:
    df = pd.read_csv(file)
    fig = plt.figure(figsize=(10, 5))
    if len(df) >20:
        plt.plot(df['PPM3'])
        plt.show()
